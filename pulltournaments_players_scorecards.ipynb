# %%
import pandas as pd
import numpy as np
import requests
import pickle
import random
from itertools import combinations
from datetime import datetime
import json
import os
from tqdm import tqdm

# %%
start_date = '2022-01-01T00:00:00'
end_date = '2023-08-30T00:00:00'
start_object = datetime.strptime(start_date, '%Y-%m-%dT%H:%M:%S')
end_object = datetime.strptime(end_date, '%Y-%m-%dT%H:%M:%S')

# %%
tournamentsendpoint = 'https://api.sportsdata.io/golf/v2/json/Tournaments?key=d656297eea034d51bdad731dcae66c84'
response = requests.get(tournamentsendpoint)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # The response content is typically in JSON format
    tournaments = response.json()
    print(tournaments)
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# [{'TournamentID': 576, 'Name': 'The Presidents Cup', 'StartDate': '2024-09-26T00:00:00', 'EndDate': '2024-09-29T00:00:00', 'IsOver': False, 'IsInProgress': False, 'Venue': 'The Royal Montreal Golf Club', 'Location': 'Montreal', 'Par': None, 'Yards': None, 'Purse': None, 'StartDateTime': None, 'Canceled': False, 'Covered': False, 'City': 'Quebec', 'State': None, 'ZipCode': None, 'Country': 'Canada', 'TimeZone': None, 'Format': 'TeamMatch', 'SportRadarTournamentID': '', 'OddsCoverage': 'Limited', 'Rounds': []}, {'TournamentID': 614, 'Name': 'TOUR Championship', 'StartDate': '2024-08-29T00:00:00', 'EndDate': '2024-09-01T00:00:00', 'IsOver': False, 'IsInProgress': False, 'Venue': 'East Lake Golf Club', 'Location': 'Atlanta, GA', 'Par': None, 'Yards': None, 'Purse': None, 'StartDateTime': None, 'Canceled': None, 'Covered': True, 'City': 'Atlanta', 'State': 'GA', 'ZipCode': None, 'Country': 'USA', 'TimeZone': 'America/New York', 'Format': 'Stroke', 'SportRadarTournamentID': '', 'OddsCoverage': 'Full', 'Rounds': []}, {'TournamentID': 613, 'Name': 'BMW Championship', 'StartDate': '2024-08-22T00:00:00', 'EndDate': '2024-08-25T00:00:00', 'IsOver': False, 'IsInProgress': False, 'Venue': 'Castle Pines Golf Club', 'Location': 'Castle Rock, CO', 'Par': None, 'Yards': None, 'Purse': None, 'StartDateTime': None, 'Canceled': None, 'Covered': True, 'City': 'Castle Rock', 'State': 'CO', 'ZipCode': None, 'Country': 'USA', 'TimeZone': 'America/Denver', 'Format': 'Stroke', 'SportRadarTournamentID': '', 'OddsCoverage': 'Full', 'Rounds': []}, {'TournamentID': 612, 'Name': 'FedEx St. Jude Championship', 'StartDate': '2024-08-15T00:00:00', 'EndDate': '2024-08-18T00:00:00', 'IsOver': False, 'IsInProgress': False, 'Venue': 'TPC Southwind', 'Location': 'Memphis, TN', 'Par': None, 'Yards': None, 'Purse': None, 'StartDateTime': None, 'Canceled': None, 'Covered': True, 'City': 'Memphis', 'State': 'TN', 'ZipCode': None, 'Country': 'USA', 'TimeZone': 'America/Chicago', 'Format': 'Stroke', 'SportRadarTournamentID': '', 'OddsCoverage': 'Full', 'Rounds': []}, {'TournamentID': 611, 'Name': 'Wyndham Championship', 'StartDate': '2024-08-08T00:00:00', 'EndDate': '2024-08-11T00:00:00', 'IsOver': False, 'IsInProgress': False, 'Venue': 'Sedgefield Country Club', 'Location': 'Greensboro, NC', 'Par': None, 'Yards': None, 'Purse': None, 'StartDateTime': None, 'Canceled': None, 'Covered': True, 'City': 'Greensboro', 'State': 'NC', 'ZipCode': None, 'Country': 'USA', 'TimeZone': 'America/New York', 'Format': 'Stroke', 'SportRadarTournamentID': '', 'OddsCoverage': 'Full', 'Rounds': []}, {'TournamentID': 610, 'Name': '3M Open', 'StartDate': '2024-07-25T00:00:00', 'EndDate': '2024-07-28T00:00:00', 'IsOver': False, 'IsInProgress': False, 'Venue': 'TPC Twin Cities', 'Location': 'Blaine, MN', 'Par': None, 'Yards': None, 'Purse': None, 'StartDateTime': None, 'Canceled': None, 'Covered': True, 'City': 'Blaine', 'State': 'MN', 'ZipCode': None, 'Country': 'USA', 'TimeZone': 'America/Chicago', 'Format': 'Stroke', 'SportRadarTournamentID': '', 'OddsCoverage': 'Full', 'Rounds': []}, {'TournamentID': 581, 'Name': 'The Open', 'StartDate': '2024-07-18T00:00:00', 'EndDate': '2024-07-21T00:00:00', 'IsOver': False, 'IsInProgress': False, 'Venue': 'Royal Troon', 'Location': 'Troon, South Ayrshire, Sco', 'Par': None, 'Yards': None, 'Purse': None, 'StartDateTime': None, 'Canceled': False, 'Covered': True, 'City': 'Troon, South Ayrshire', 'State': None, 'ZipCode': None, 'Country': 'SCO', 'TimeZone': 'Europe/London', 'Format': 'Stroke', 'SportRadarTournamentID': '', 'OddsCoverage': 'Full', 'Rounds': []}, {'TournamentID': 609, 'Name': 'Barracuda Championship', 'StartDate': '2024-07-18T00:00:00', 'EndDate': '2024-07-21T00:00:00', 'IsOver': False, 'IsInProgress': False, 'Venue': 'Tahoe Mountain Club (Old Greenwood)', 'Location': 'Truckee, CA', 'Par': None, 'Yards': None, 'Purse': None, 'StartDateTime': None, 'Canceled': None, 'Covered': False, 'City': 'Truckee', 'State': 'CA', 'ZipCode': None, 'Country ...

# %%
idtoname = {}
nametoid = {}
for t in tournaments:
    t_start_obj = datetime.strptime(t['StartDate'], '%Y-%m-%dT%H:%M:%S')
    t_end_obj = datetime.strptime(t['EndDate'], '%Y-%m-%dT%H:%M:%S')
    if start_object < t_start_obj and end_object > t_end_obj:
        tid = t['TournamentID']
        name = t['Name']
        idtoname[tid] = name
        nametoid[name] = tid
        print(name)
        
with open('metadata/touridtoname.json', 'w') as json_file:
    json.dump(idtoname, json_file)
with open('metadata/tournametoid.json', 'w') as json_file:
    json.dump(nametoid, json_file)
# Out:
# TOUR Championship
# BMW Championship
# FedEx St. Jude Championship
# Wyndham Championship
# 3M Open
# Barracuda Championship
# The Open
# Barbasol Championship
# Genesis Scottish Open
# John Deere Classic
# Rocket Mortgage Classic
# Travelers Championship
# U.S. Open
# RBC Canadian Open
# The Memorial Tournament pres. by Workday
# Charles Schwab Challenge
# PGA Championship
# AT&T Byron Nelson
# Wells Fargo Championship
# Mexico Open
# Zurich Classic of New Orleans
# RBC Heritage
# Masters Tournament
# Valero Texas Open
# Corales Puntacana Championship
# WGC-Dell Technologies Match Play
# Valspar Championship
# THE PLAYERS Championship
# Puerto Rico Open
# Arnold Palmer Invitational pres. by Mastercard
# The Honda Classic
# The Genesis Invitational
# WM Phoenix Open
# AT&T Pebble Beach Pro-Am
# Farmers Insurance Open
# The American Express
# Sony Open in Hawaii
# Sentry Tournament of Champions
# QBE Shootout
# Hero World Challenge
# The RSM Classic
# Cadence Bank Houston Open
# World Wide Technology Championship at Mayakoba
# Butterfield Bermuda Championship
# THE CJ CUP in South Carolina
# ZOZO CHAMPIONSHIP
# Shriners Children's Open
# Sanderson Farms Championship
# Presidents Cup
# Fortinet Championship
# TOUR Championship
# BMW Championship
# FedEx St. Jude Championship
# Wyndham Championship
# Rocket Mortgage Classic
# 3M Open
# Barracuda Championship
# The Open
# Barbasol Championship
# Genesis Scottish Open
# John Deere Classic
# Travelers Championship
# U.S. Open
# RBC Canadian Open
# the Memorial Tournament pres. by Workday
# Charles Schwab Challenge
# PGA Championship
# AT&T Byron Nelson
# Wells Fargo Championship
# Mexico Open
# Zurich Classic of New Orleans
# RBC Heritage
# Masters Tournament
# Valero Texas Open
# Corales Puntacana Championship
# WGC-Dell Technologies Match Play
# Valspar Championship
# THE PLAYERS Championship
# Puerto Rico Open
# Arnold Palmer Invitational pres. by Mastercard
# The Honda Classic
# The Genesis Invitational
# WM Phoenix Open
# AT&T Pebble Beach Pro-Am
# Farmers Insurance Open
# The American Express
# Sony Open in Hawaii
# Sentry Tournament of Champions

# %%
playeridtoname = {}
nametoplayerid = {}

with open('metadata/touridtoname.json', 'r') as json_file:
    tour_dict = json.load(json_file)
tournaments = list(tour_dict.keys())

for t in tqdm(tournaments):
    #teetimes = {}
    if not os.path.exists(f'tournaments/{t}'):
        os.makedirs(f'tournaments/{t}')
    leaderboardurl = f'https://api.sportsdata.io/golf/v2/json/Leaderboard/{t}?key=d656297eea034d51bdad731dcae66c84'
    response = requests.get(leaderboardurl)
    if response.status_code == 200:
        data = response.json()
    else:
        print(f"Request failed with status code: {response.status_code}")
    for player in data['Players']:
        scores = []
        name = player['Name']
        playerid = player['PlayerID']
        if not os.path.exists(f'tournaments/{t}/{playerid}'):
            os.makedirs(f'tournaments/{t}/{playerid}')
        #teetimes[playerid] = {}
        teetimes = {}
        if playerid not in (playeridtoname.keys()):
            playeridtoname[playerid] = name
            nametoplayerid[name] = playerid
        scorecardpath = f'tournaments/{t}/{playerid}/scorecard.pkl'
        ttpath = f'tournaments/{t}/{playerid}/teetime.json'
        for r in player['Rounds']:
            teetimes[r['Number']] = [r['TeeTime'], r['BackNineStart']]
            roundscores = []
            for hole in r['Holes']:
                roundscores.append(hole['ToPar'])
            scores.append(roundscores)
        #print(scores)
        with open(scorecardpath, 'wb') as file:
            pickle.dump(scores, file)
        with open(ttpath, 'w') as json_file:
            json.dump(teetimes, json_file)

with open('metadata/playeridtoname.json', 'w') as json_file:
    json.dump(playeridtoname, json_file)
with open('metadata/nametoplayerid.json', 'w') as json_file:
    json.dump(nametoplayerid, json_file)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 88/88 [01:25<00:00,  1.03it/s]

# %%
nametoplayerid
# Out:
# {'Viktor Hovland': 40003218,
#  'Xander Schauffele': 40001638,
#  'Wyndham Clark': 40002651,
#  'Rory McIlroy': 40000965,
#  'Patrick Cantlay': 40000216,
#  'Tommy Fleetwood': 40000432,
#  'Collin Morikawa': 40002471,
#  'Scottie Scheffler': 40001274,
#  'Keegan Bradley': 40000152,
#  'Sam Burns': 40000194,
#  'Max Homa': 40000638,
#  'Adam Schenk': 40001686,
#  'Matt Fitzpatrick': 40000430,
#  'Russell Henley': 40000615,
#  'Sepp Straka': 40002785,
#  'Rickie Fowler': 40000003,
#  'Tyrrell Hatton': 40000596,
#  'Lucas Glover': 40000509,
#  'Jon Rahm': 40001199,
#  'Tony Finau': 40000423,
#  'Si Woo Kim': 40000764,
#  'Joo-Hyung Kim': 40004287,
#  'Brian Harman': 40000585,
#  'Sung-Jae Im': 40002605,
#  'Nick Taylor': 40001424,
#  'Corey Conners': 40000270,
#  'Jordan Spieth': 40000004,
#  'Jason Day': 40000314,
#  'Emiliano Grillo': 40000540,
#  'Taylor Moore': 40002348,
#  'Chris Kirk': 40000011,
#  'Harris English': 40000387,
#  'Denny McCarthy': 40000946,
#  'Andrew Putnam': 40001189,
#  'Adam Svensson': 40001414,
#  'Sahith Theegala': 40002486,
#  'Cameron Young': 40003609,
#  'Tom Hoge': 40000634,
#  'JT Poston': 40001971,
#  'Justin Rose': 40000013,
#  'Eric Cole': 40002026,
#  'Patrick Rodgers': 40001232,
#  'Cam Davis': 40002474,
#  'Kurt Kitayama': 40002249,
#  'Brendon Todd': 40001447,
#  'Byeong-Hun An': 40000045,
#  'Adam Hadwin': 40000561,
#  'Lee Hodges': 40003242,
#  'Seamus Power': 40001685,
#  'Nick Hardy': 40000584,
#  'Mackenzie Hughes': 40000659,
#  'Hideki Matsuyama': 40000017,
#  'Beau Hossler': 40000647,
#  'Stephan Jaeger': 40000695,
#  'Ben Griffin': 40002343,
#  'J.J. Spaun': 40001353,
#  'Sam Ryder': 40001870,
#  'Taylor Montgomery': 40003667,
#  'Sam Stevens': 40004729,
#  'Brandon Wu': 40003616,
#  'Keith Mitchell': 40001680,
#  'Davis Riley': 40001224,
#  'Vincent Norrman': 40003684,
#  'Aaron Rai': 40002578,
#  'Hayden Buckley': 40003346,
#  'Matthew NeSmith': 40001053,
#  'Thomas Detry': 40002573,
#  'Matt Kuchar': 40000014,
#  'Alex Smalley': 40002645,
#  'Mark Hubbard': 40000657,
#  'Austin Eckroat': 40003612,
#  'Billy Horschel': 40000016,
#  'Michael Kim': 40000763,
#  'Webb Simpson': 40001313,
#  'Adam Scott': 40000010,
#  'Justin Thomas': 40001434,
#  'Charley Hoffman': 40000632,
#  'Ludvig Aberg': 40003252,
#  'Robert Streb': 40001388,
#  'Nicolai Hojgaard': 40003193,
#  'Ryan Brehm': 40000162,
#  'Luke Donald': 40000345,
#  'Matthias Schmid': 40003650,
#  'Davis Thompson': 40003769,
#  'Nicholas Lindheim': 40000866,
#  'Chez Reavie': 40001211,
#  'Austin Smotherman': 40002629,
#  'Gary Woodland': 40001594,
#  'Chesson Hadley': 40000560,
#  'Kelly Kraft': 40000789,
#  'Andrew Novak': 40002911,
#  'Sam Bennett': 40004526,
#  'Tyler Duncan': 40000363,
#  'Alexander Noren': 40001064,
#  'Greyson Sigg': 40002910,
#  'David Lipsky': 40000868,
#  'Scott Piercy': 40001156,
#  'Brandt Snedeker': 40001343,
#  'Matt Wallace': 40002569,
#  'Kyle Westmoreland': 40003702,
#  'Peter Kuest': 40004028,
#  'Christiaan Bezuidenhout': 40002583,
#  'Ze-Cheng Dou': 40000348,
#  'Doug Ghim': 40003037,
#  'Nate Lashley': 40000817,
#  'Shane Lowry': 40000890,
#  'Max McGreevy': 40003541,
#  'Dylan Wu': 40003629,
#  'Martin Laird': 40000802,
#  'Troy Merritt': 40000987,
#  'Scott Stallings': 40001361,
#  'Joel Dahmen': 40000302,
#  'Cheng Tsung Pan': 40001109,
#  'Michael Gligic': 40000507,
#  'Trey Mullinax': 40001030,
#  'Carson Young': 40004329,
#  'Wesley Bryan': 40001666,
#  'Jim Herman': 40000620,
#  'Richy Werenski': 40001540,
#  'Yechun Yuan': 40003225,
#  'Tyson Alexander': 40000034,
#  'Ryan Armour': 40000059,
#  'Akshay Bhatia': 40003519,
#  'Zac Blair': 40000129,
#  'Cameron Champ': 40002650,
#  'Stewart Cink': 40000248,
#  'Trevor Cone': 40002204,
#  'Austin Cook': 40000272,
#  'MJ Daffue': 40003860,
#  'Jason Dufner': 40000358,
#  'Nicolas Echavarria': 40003315,
#  'Harrison Endycott': 40002979,
#  'Dylan Frittelli': 40002512,
#  'Brice Garnett': 40000482,
#  'Brian Gay': 40000491,
#  'Ryan Gerard': 40005232,
#  'Will Gordon': 40003663,
#  'Estanislao Goya': 40000525,
#  'Brent Grant': 40002478,
#  'James Hahn': 40000564,
#  'Paul Haley II': 40000567,
#  'Harry Hall': 40003725,
#  'Scott Harrington': 40000588,
#  'Kramer Hickok': 40001675,
#  'Garrick Higgo': 40003542,
#  'Zach Johnson': 40000012,
#  'Seong-Hyeon Kim': 40003586,
#  'Patton Kizzire': 40000772,
#  'Russell Knox': 40000778,
#  'Andrew Landry': 40000808,
#  'Kyoung-Hoon Lee': 40000836,
#  'David Lingmerth': 40000867,
#  'Luke List': 40000869,
#  'Adam Long': 40000877,
#  'Davis Love III': 40000884,
#  'Justin Lower': 40000887,
#  'Peter Malnati': 40000915,
#  'Ben Martin': 40000924,
#  'Brandon Matthews': 40002795,
#  'Ryan Moore': 40001016,
#  'Henrik Norlander': 40001065,
#  'Augusto Nunez': 40001786,
#  'Ryan Palmer': 40001107,
#  'Taylor Pendrith': 40001132,
#  'Chad Ramey': 40001202,
#  'Doc Redman': 40003036,
#  'Kyle Reifers': 40001215,
#  'Kevin Roy': 40004304,
#  'Rory Sabbatini': 40001254,
#  'Matthias Schwab': 40002495,
#  'Robby Shelton': 40001303,
#  'Kevin Streelman': 40001390,
#  'Brian Stuard': 40001396,
#  'Justin Suh': 40002378,
#  'Callum Tarren': 40002108,
#  'Ben Taylor': 40001423,
#  'Kevin Tway': 40001473,
#  'Erik Van Rooyen': 40002547,
#  'Jimmy Walker': 40000009,
#  'Nick Watney': 40001525,
#  'Trevor Werbylo': 40004843,
#  'Danny Willett': 40001565,
#  'Kevin Yu': 40003151,
#  'Harry Higgs': 40002004,
#  'Cameron Percy': 40001136,
#  'Jonathan Byrd': 40000196,
#  'Martin Trainer': 40001458,
#  'Satoshi Kodaira': 40000782,
#  'Henry Lebioda': 40002346,
#  'Aaron Baddeley': 40000071,
#  'Jon Mayer': 40005745,
#  'Ryan Fox': 40000448,
#  'Cody Gribble': 40000534,
#  "Sean O'Hair": 40001071,
#  'Grayson Murray': 40001038,
#  'Seung-Yul Noh': 40001063,
#  'Chris Stroud': 40001394,
#  'Kevin Chappell': 40000236,
#  'Tommy Gainey': 40000468,
#  'Joseph Lane': 40003669,
#  'Sung-Hoon Kang': 40000731,
#  'Jonas Blixt': 40000136,
#  'William McGirt': 40000959,
#  'Frankie Capan': 40001864,
#  'Kaito Onishi': 40004964,
#  'Chad Collins': 40000263,
#  'Lanto Griffin': 40000535,
#  'Thomas Lehman': 40003903,
#  'Preston Summerhays': 40004308,
#  'Ricky Barnes': 40000095,
#  'Derek Hitchner': 40005717,
#  'Eric Rolland': 40005718,
#  'David Hearn': 40000602,
#  'Geoff Ogilvy': 40001084,
#  'Caleb Vanarragon': 40005719,
#  'Ted Potter Jr': 40001173,
#  'Greg Chalmers': 40000234,
#  'Daniel Gale': 40003085,
#  'Alex Gaugert': 40004957,
#  'Noah Hofman': 40004004,
#  'Derek Ernst': 40000391,
#  'Derek Lamely': 40000806,
#  'Scott Brown': 40000182,
#  'Aaron Cockerill': 40002203,
#  'Bastien Amat': 40005633,
#  'Maximilian Kieffer': 40000752,
#  'Joakim Lagergren': 40002167,
#  'Chase Hanna': 40003794,
#  'Sebastian Garcia Rodriguez': 40003057,
#  'Alexander Lévy': 40000853,
#  'Andy Sullivan': 40001402,
#  'Edoardo Molinari': 40001011,
#  'Jason Scrivener': 40001974,
#  'Nathan Kimsey': 40002657,
#  'James Morrison': 40001023,
#  'Johannes Veerman': 40002587,
#  'Rico Hoey': 40002741,
#  'Marcus Kinhult': 40002633,
#  'Marcus Armitage': 40002608,
#  'Sean Crocker': 40002924,
#  'Ryo Hisatsune': 40004833,
#  'J.C. Ritchie': 40002614,
#  'Sebastian Söderberg': 40002360,
#  'Julien Guerrier': 40000546,
#  'Jens Dantorp': 40002537,
#  'Frederik Schott': 40004705,
#  'John Catlin': 40002200,
#  'Ashun Wu': 40001602,
#  'Lukas Nemecz': 40002729,
#  'Simon Forsstrom': 40002585,
#  'Matthieu Pavon': 40002576,
#  'Robin Sciot-Siegrist': 40002697,
#  'Scott Jamieson': 40000697,
#  'Wil Besseling': 40002835,
#  'Martin Leth Simonsen': 40003335,
#  'Jeong-Weon Ko': 40003750,
#  'Mikael Lindberg': 40002895,
#  'Angel Hidalgo': 40003056,
#  'Jeremy Freiburghaus': 40003877,
#  'Dale Whitnell': 40003695,
#  'Marcus Helligkilde': 40003240,
#  'Niklas Nã¸rgaard Mã¸ller': 40005302,
#  'Marcel Schneider': 40002845,
#  'Nicolai Von Dellingshausen': 40002642,
#  'J.J. Henry': 40000617,
#  'Jesse Mueller': 40001026,
#  'Ethan Cairns': 40005716,
#  'Adrien Saddier': 40002579,
#  'Masahiro Kawamura': 40000739,
#  'Oliver Hundeboll': 40005710,
#  'Tapio Pulkkanen': 40002632,
#  'Santiago Tarrío': 40002888,
#  'Fabrizio Zanotti': 40001621,
#  'Charles Porter': 40005494,
#  'Corey Pereira': 40003243,
#  'Louis De Jager': 40002758,
#  'Alexander Knappe': 40002519,
#  'Darius Van Driel': 40002564,
#  'Daan Huizing': 40002554,
#  'Matt Ryan': 40002928,
#  'Clément Sordet': 40002427,
#  'Michael Duncan': 40004943,
#  'Grant Booth': 40003236,
#  'Eddy Lai': 40005720,
#  'Shubhankar Sharma': 40002607,
#  'Matthew Jordan': 40003285,
#  'Henrik Stenson': 40001373,
#  'Laurie Canter': 40000215,
#  'Alex Fitzpatrick': 40003219,
#  'Antoine Rozner': 40002744,
#  'Adrian Meronk': 40002818,
#  'Louis Oosthuizen': 40001092,
#  'Matthew Southgate': 40001351,
#  'Rich Bland': 40000133,
#  'Romain Langasque': 40000810,
#  'Patrick Reed': 40000002,
#  'Cameron Smith': 40001333,
#  'Oliver Wilson': 40001578,
#  'Alexander Björk': 40002491,
#  'Min Woo Lee': 40002925,
#  'Hurly Long': 40003178,
#  'Victor Perez': 40002711,
#  'Marcel Siem': 40001308,
#  'Jordan L. Smith': 40002515,
#  'Abraham Ancer': 40000047,
#  'Michael Stewart': 40005415,
#  'Zach J. Johnson': 40003239,
#  'Adrián Otaegui': 40002367,
#  'Brandon Robinson-Thompson': 40003870,
#  'Bryson DeChambeau': 40000322,
#  'Rikuya Hoshino': 40002721,
#  'Pádraig Harrington': 40000587,
#  'Brooks Koepka': 40000007,
#  'Guido Migliozzi': 40002829,
#  'Richie Ramsay': 40001203,
#  'Sami Valimaki': 40003478,
#  'Joost Luiten': 40000893,
#  'Robert MacIntyre': 40002950,
#  'Thomas Pieters': 40001157,
#  'Christo Lamprecht': 40003417,
#  'Thriston Lawrence': 40002899,
#  'Zack Fischer': 40000425,
#  'Adri Arnaus': 40002748,
#  'Kyle Barker': 40002949,
#  'Haydn Barron': 40005029,
#  'Dan Bradbury': 40005310,
#  'Jorge Campillo': 40000210,
#  'Alejandro Canizares': 40000213,
#  'Tiger Christensen': 40005616,
#  'Darren Clarke': 40000251,
#  'Harrison Crowe': 40005091,
#  'John Daly': 40000304,
#  'Ernie Els': 40000383,
#  'Nacho Elvira': 40000385,
#  'Oliver Farr': 40000404,
#  'Ewen Ferguson': 40003116,
#  'Mateo Fernandez De Oliveira': 40005551,
#  'Talor Gooch': 40000518,
#  'Branden Grace': 40000527,
#  'Seungsu Han': 40002618,
#  'Lucas Herbert': 40002752,
#  'Kazuki Higa': 40003084,
#  'Daniel Hillier': 40003614,
#  'Kensei Hirata': 40005256,
#  'Rasmus Hojgaard': 40003220,
#  'Hiroshi Iwata': 40000689,
#  'Atiwit Janewattanano': 40002541,
#  'Dustin Johnson': 40000015,
#  'Takumi Kanaya': 40002913,
#  'Kyung-Nam Kang': 40002611,
#  'Taichi Kho': 40005499,
#  'Bio Kim': 40000755,
#  'Pablo Larrazábal': 40000815,
#  'David Micheluzzi': 40003367,
#  'Phil Mickelson': 40000991,
#  'Francesco Molinari': 40001012,
#  'Keita Nakajima': 40003373,
#  'Joaquin Niemann': 40002644,
#  'Thorbjorn Olesen': 40001089,
#  'Yannik Paul': 40003920,
#  'Marco Penge': 40003697,
#  'Martin Rohwer': 40003086,
#  'Kalle Samooja': 40002732,
#  'Charl Schwartzel': 40001290,
#  'Taiga Semikawa': 40005292,
#  'Callum Shinkwin': 40002146,
#  'Travis Smyth': 40002770,
#  'Ockert Strydom': 40002574,
#  'Connor Syme': 40002666,
#  'Marc Warren': 40001523,
#  'Gunner Wiebe': 40001556,
#  'Kazuki Yasumori': 40005623,
#  'Jose Luis Ballester Barrio': 40005711,
#  'Alex Maguire': 40005712,
#  'Connor McKinney': 40005713,
#  'Graeme Robertson': 40005714,
#  'Daniel Brown': 40004911,
#  'David Ravetto': 40003751,
#  'Jayden Trey Schaper': 40003771,
#  'Christoffer Bring': 40004852,
#  'Chris Nido': 40002501,
#  'John Axelsen': 40004372,
#  'Bo Hoag': 40001860,
#  'Bo Van Pelt': 40001484,
#  'Alejandro Del Rey': 40003058,
#  'David Ford': 40005705,
#  'Niklas Norgaard Moller': 40002773,
#  'Sang-Moon Bae': 40000072,
#  'Todd Clements': 40003470,
#  'Ben Crane': 40000287,
#  'Alejandro Del Ray': 40005632,
#  'Jamie Donaldson': 40000346,
#  'Bryce Easton': 40002898,
#  'Manu Gandas': 40003020,
#  'Robert Garrigus': 40000484,
#  'Deon Germishuys': 40003430,
#  'Wes Homan': 40000639,
#  'Ryuji Imada': 40000676,
#  'Richard Johnson': 40000712,
#  'Soren Kjeldsen': 40000773,
#  'Mike Lorenzo-Vera': 40001876,
#  'John Parry': 40001123,
#  'D.A. Points': 40001163,
#  'Kevin Stadler': 40001359,
#  'Stephen Stallings Jr.': 40003660,
#  'Kyle Stanley': 40001365,
#  'Josh Teater': 40001426,
#  'D.J. Trahan': 40001457,
#  'Johnson Wagner': 40001510,
#  'Vince Whaley': 40003465,
#  'Omar Uresti': 40001478,
#  'Brian Davis': 40000311,
#  'Matt Every': 40000401,
#  'Jeff Overton': 40001101,
#  'Daniel Chopra': 40000245,
#  'Steve Stricker': 40001392,
#  'K.J. Choi': 40000244,
#  'Chad Campbell': 40000206,
#  'Heath Slocum': 40001327,
#  'Joe Durant': 40000367,
#  'Trey Cox': 40005704,
#  'Oliver Jorgensen': 40003592,
#  'Jesse Massie': 40005706,
#  'Pedro Figueiredo': 40002747,
#  'Duffy Waldorf': 40001514,
#  'Kiradech Aphibarnrat': 40000053,
#  'Andrew Wilson': 40003649,
#  'Joshua Lee': 40005461,
#  'Carlos Franco': 40000452,
#  'Thomas Aiken': 40000031,
#  'John Rollins': 40001235,
#  'Maxwell Moldovan': 40005229,
#  'Chip McDaniel': 40003205,
#  'Matthew Sharpstene': 40004754,
#  'Robert Gamez': 40000472,
#  'Jason Bohn': 40000140,
#  'Frank Lickliter II': 40000861,
#  'Jonathan Kaye': 40000740,
#  'Will MacKenzie': 40000903,
#  'Len Mattiace': 40000935,
#  'Steven Bowditch': 40000150,
#  'Gabriel Hjertstedt': 40001704,
#  'Fredrik Jacobson': 40000693,
#  'Andres Romero': 40001236,
#  'Glen Day': 40000313,
#  'Grant Forrest': 40000441,
#  'Calum Hill': 40003156,
#  'Tom McKibbin': 40003147,
#  'Julien Brun': 40000185,
#  'Thomas Bjorn': 40000126,
#  'Gavin Green': 40002458,
#  'Nick Bachem': 40003878,
#  'Matthew Baldwin': 40000084,
#  'Oliver Bekker': 40000108,
#  'Joseph Bramlett': 40000155,
#  'Rafael Cabrera Bello': 40000201,
#  'Nicolas Colsaerts': 40000266,
#  'Ross Fisher': 40000427,
#  'Daniel Gavins': 40003400,
#  'Yeongsu Kim': 40004359,
#  'David Law': 40003180,
#  'Hao-Tong Li': 40000859,
#  'Zander Lombard': 40002371,
#  'Richard Mansell': 40003653,
#  'Eddie Pepperell': 40001135,
#  'Yoseop Seo': 40003620,
#  'Justin Walters': 40001519,
#  'Paul Waring': 40001522,
#  'William Mouw': 40005227,
#  'Michael Thorbjornsen': 40003594,
#  'Yuto Katsuragawa': 40004876,
#  'Gordon Sargent': 40005549,
#  'Marcus Byrd': 40005090,
#  'Ross Steelman': 40005636,
#  'Camilo Villegas': 40001501,
#  'Jay Giannetto': 40005693,
#  'Tommy Kuhl': 40005694,
#  'Arjun Atwal': 40000065,
#  'George McNeill': 40000978,
#  'Anders Larson': 40005695,
#  'Reid Martin': 40005696,
#  'Mark Hensby': 40000618,
#  'Paul Goydos': 40000526,
#  'Brett Stegmaier': 40001372,
#  'Chase Johnson': 40004178,
#  'Kyle Martin': 40001902,
#  'Aldrich Potgieter': 40005299,
#  'Fabian Gomez': 40000514,
#  'Andy Spencer': 40004728,
#  'Andrew Svoboda': 40001415,
#  'Ryan Blaum': 40000135,
#  'J.B. Holmes': 40000008,
#  'Benjamin James': 40005268,
#  'Kevin Kisner': 40000770,
#  'Aaron Wise': 40002362,
#  'Ryutaro Nagano': 40002540,
#  'Sergio Garcia': 40000479,
#  'David Puig': 40005631,
#  'Sebastian Munoz': 40001682,
#  'Jacob Solomon': 40005482,
#  'Ben Carr': 40005520,
#  'Ryo Ishikawa': 40000686,
#  'Paul Barjon': 40002338,
#  'Michael Brennan': 40005053,
#  'Barclay Brown': 40005300,
#  'Olin Browne': 40000184,
#  'Christian Cavaliere': 40005627,
#  'Gunn Charoenkul': 40002019,
#  'Patrick Cover': 40004374,
#  'Ding Wenyi': 40004376,
#  'Nick Dunlap': 40004698,
#  'J.J. Grey': 40005037,
#  'Jordan Gumberg': 40003248,
#  'Berry Henson': 40000619,
#  'David Horsey': 40000645,
#  'Martin Kaymer': 40000741,
#  'Matthew McClean': 40005550,
#  'Mac Meissner': 40004527,
#  'Omar Morales': 40005572,
#  'Kyle Mueller': 40002373,
#  'Wilco Nienaber': 40003422,
#  'David Nyfjall': 40003686,
#  'Carlos Ortiz': 40001097,
#  'Mito Pereira': 40001788,
#  'Alex Schaake': 40004858,
#  'Jesse Schutte': 40001289,
#  'Isaac Simmons': 40005630,
#  'Roger Sloan': 40001326,
#  'Austen Truslow': 40001463,
#  'Karl Vilips': 40005626,
#  'Alexander Yang': 40005629,
#  'Brendan Valdes': 40005628,
#  'Mike Weir': 40001536,
#  'Stuart Macdonald': 40004007,
#  'Wil Bateman': 40001727,
#  'Michael Block': 40000138,
#  'Myles Creighton': 40005216,
#  'Bill Haas': 40000005,
#  'Jae Yong Kim': 40002248,
#  'Jake Knapp': 40000775,
#  'Philip Knowles': 40003050,
#  'Maverick McNealy': 40000977,
#  'Étienne Papineau': 40005047,
#  'Benjamin Silverman': 40001309,
#  'Sebastian Szirmak': 40002292,
#  'Johnny Travale': 40005220,
#  'Luis Carrera': 40005621,
#  'Taylor Durham': 40005622,
#  'David Carey': 40004975,
#  'Ryan Hall': 40004881,
#  'Drew Nesbitt': 40002686,
#  'Carl Pettersson': 40001151,
#  'Daniel Kim': 40002685,
#  'Ted Purdy': 40001187,
#  'Charlie Beljan': 40000109,
#  'Eric Axley': 40000067,
#  'Christopher Gotterup': 40005060,
#  'Erik Compton': 40000267,
#  'Parker Coody': 40004332,
#  'Pierceson Coody': 40004700,
#  'Cole Hammer': 40000575,
#  'Harold Varner': 40001490,
#  'Dean Burmester': 40001861,
#  'Sihwan Kim': 40002473,
#  'Steven Alker': 40000035,
#  'Alex Beach': 40002694,
#  'Matt Cahill': 40005591,
#  'Paul Casey': 40000006,
#  'Anthony Cordes': 40004360,
#  'Jesse Droemer': 40003062,
#  'Chris French': 40005592,
#  'Steve Holmes': 40000637,
#  'Colin Inglis': 40005159,
#  'Sadom Kaewkanjana': 40003483,
#  'Ben Kern': 40003237,
#  'J.J. Killeen': 40000753,
#  'Greg Koch': 40004719,
#  'Anirban Lahiri': 40000018,
#  'Shaun Micheel': 40000989,
#  'Kenny Pigman': 40002480,
#  'John Somers': 40003547,
#  'Josh Speight': 40002450,
#  'Brendan Steele': 40001369,
#  'Wyatt Worthington': 40002452,
#  'Y.E. Yang': 40001607,
#  'Russell Grove': 40005593,
#  'Gabe Reynolds': 40005594,
#  'Chris Sanger': 40005595,
#  'Braden Shattuck': 40005596,
#  'Jeremy Wells': 40005597,
#  'Michael Thompson': 40001439,
#  'William Knauth': 40005586,
#  'Jeffrey Kang': 40002245,
#  'Bobby Massa': 40000930,
#  'Taylor Bibbs': 40005283,
#  'Logan McCracken': 40002263,
#  'Boo Weekley': 40001532,
#  'Trace Crowe': 40002678,
#  'Alejandro Tosti': 40003764,
#  'Morgan Deneen': 40004390,
#  'Austin Greaser': 40005104,
#  'Quinn Riley': 40005214,
#  'Danny Guise': 40004831,
#  'Willie Mack': 40001946,
#  'Ryan Cole': 40005584,
#  'Anders Albertson': 40001664,
#  'Sebastian Vazquez': 40001493,
#  'Raul Pereda': 40002157,
#  'Zachary Bauchou': 40003213,
#  'Cristobal Del Solar': 40003065,
#  'Jose Cristobal Islas': 40005126,
#  'Roberto Lebrija': 40002154,
#  'Alvaro Ortiz': 40001951,
#  'Jose De Jesus Rodriguez': 40001233,
#  'Jose Toledo': 40001450,
#  'Steve Jurgensen': 40005571,
#  'Jim Furyk': 40000466,
#  'Tommy Gibson': 40004536,
#  'Will Zalatoris': 40001620,
#  'Fred Couples': 40000285,
#  'Jason Kokrak': 40000785,
#  'Bernhard Langer': 40000811,
#  'Sandy Lyle': 40000898,
#  'Larry Mize': 40001009,
#  'Kevin Na': 40001044,
#  'Jose Maria Olazabal': 40001087,
#  'Vijay Singh': 40001317,
#  'Bubba Watson': 40000001,
#  'Tiger Woods': 40000019,
#  'Roberto Diaz': 40000331,
#  'Chandler Phillips': 40003717,
#  'JJ Wood': 40002690,
#  'Peter Lansburgh': 40005548,
#  'Rafael Campos': 40000211,
#  'Erik Barnes': 40001694,
#  'Dominic Bozzelli': 40001665,
#  'Juan Jose Guerra': 40002002,
#  'Justin Hicks': 40000623,
#  'Justin Kim': 40002056,
#  'Rhadames Pena': 40003041,
#  'Hiram Silfa': 40001715,
#  'Jhonattan Vegas': 40001495,
#  'Cougar Collins': 40005529,
#  'Thomas Longbella': 40005530,
#  'Kyle Maxwell': 40005531,
#  'Cameron Beckman': 40000105,
#  'Tommy Armour III': 40000060,
#  'Neal Lancaster': 40000807,
#  'Parker McLachlin': 40000969,
#  'Spike McRoy': 40002463,
#  'Nick Gabrelcik': 40005524,
#  'John Vanderlaan': 40003207,
#  'Alex Chiarella': 40003636,
#  'Peter Knade': 40004524,
#  'Vaughn Taylor': 40001425,
#  'Jerry Kelly': 40000743,
#  'Noah Goodwin': 40003112,
#  'Jiri Zuska': 40003676,
#  'Brandon Harkins': 40001757,
#  'Robert Calvesbert': 40002498,
#  'Edward Figueroa': 40000422,
#  'Tim Cantwell': 40005200,
#  'Diego Saavedra-Davila': 40005518,
#  'Guy Boros': 40000143,
#  'Julian Etulain': 40000399,
#  'Brendon De Jonge': 40000316,
#  'Tom Adrounie': 40005519,
#  'Charlie Wi': 40001554,
#  'Mike Springer': 40001357,
#  'Dick Mast': 40000931,
#  'Chase Seiffert': 40001294,
#  'Scott Gutschewski': 40000553,
#  'Seth Reeves': 40002772,
#  'Ben Kohles': 40000783,
#  'Curtis Thompson': 40001436,
#  'Jim Knous': 40002481,
#  'Brandon Hagy': 40000563,
#  'David Skinns': 40001324,
#  'Jared Wolfe': 40002742,
#  'Kamaiu Johnson': 40004382,
#  'Brett Drewitt': 40001671,
#  'Tyler Collet': 40004393,
#  'Andrew Kozan': 40000787,
#  'Danny Lee': 40000833,
#  'Jack Wall': 40005509,
#  'Michael Hopper': 40000642,
#  'John Huh': 40000661,
#  'Andre Metzger': 40003973,
#  'Dalton Ward': 40001521,
#  'Brett White': 40005042,
#  "Paul O'Hara": 40003127,
#  'Tom Johnson': 40000713,
#  'RJ Manke': 40005222,
#  'John Pak': 40004311,
#  'Garett Reband': 40004819,
#  'Patrick Welch': 40005430,
#  'Michael Herrera': 40005491,
#  'Joey Vrzich': 40005492,
#  'Spencer Levin': 40000852,
#  'Caleb Surratt': 40005446,
#  'Harrison Kingsley': 40005493,
#  'Joseph Winslow': 40001996,
#  'Blaze Akana': 40005480,
#  'Kohei Okada': 40005479,
#  'Michael Castillo': 40005481,
#  'George Markham': 40003925,
#  'Lexi Thompson': 40002912,
#  'Jacob Bridgeman': 40005133,
#  'Palmer Jackson': 40005444,
#  'Spencer Ralston': 40004112,
#  'Tim Weinhart': 40001535,
#  'Conner Godsey': 40004528,
#  'Bryson Nimmer': 40003481,
#  'Travis Vick': 40004909,
#  'Walker Lee': 40002647,
#  'Lukas Euler': 40003291,
#  'Sean Jacklin': 40001764,
#  'Brad Adamonis': 40000022,
#  'Isidro Benitez': 40003372,
#  'Armando Favela': 40000409,
#  'Enrique Marin Santander': 40005456,
#  'Travis Trace': 40003638,
#  'Chandler Blanchet': 40003722,
#  'Jarryd Dillas': 40003757,
#  'Clay Feagler': 40004859,
#  'Aaron Jarvis': 40005105,
#  'James Nicholas': 40004176,
#  'Michael Sims': 40001314,
#  'John Merrick': 40000986,
#  'Nick Jones': 40005445,
#  'Kim Swan': 40005448,
#  'Sang-Hyun Park': 40003191,
#  'Chanmin Jung': 40005431,
#  'Yongjun Bae': 40003729,
#  'Sanghun Shin': 40004540,
#  'Mikumu Horikawa': 40002762,
#  'Naoyuki Kataoka': 40004702,
#  'Aguri Iwasaki': 40004834,
#  'Riki Kawamoto': 40004341,
#  'Tomoharu Ohtsuki': 40003118,
#  'Shugo Imahira': 40002429,
#  'Derek Deminsky': 40005429,
#  'Xue-Wen Luo': 40002065,
#  'Ryan Ruffels': 40001245,
#  'Jared Sawada': 40001268,
#  'Wilson Furr': 40003347,
#  'Jackson Suber': 40005078,
#  'Joseph Hanko': 40005423,
#  'Sam Murphy': 40005424,
#  'Brice Wilkinson': 40005425,
#  'Quade Cummins': 40004369,
#  'John Augenstein': 40003543,
#  'Scott De Borba': 40003833,
#  'Alex Lee': 40004151,
#  'Taylor Lowe': 40005413,
#  'Marc Leishman': 40000842,
#  'Cameron Tringale': 40001460,
#  'Blake Mcshea': 40005360,
#  'Joshua Creel': 40003072,
#  'Trent Phillips': 40003664,
#  'Dawie Van Der Walt': 40001482,
#  'Mickey Demorat': 40003154,
#  'Rick Lamb': 40001846,
#  'KK Limbhasut': 40003829,
#  'Chris Naegel': 40001045,
#  'Ben Cook': 40003573,
#  'Morgan Hoffmann': 40000633,
#  'Luke Guthrie': 40000552,
#  'Erik Flores': 40000437,
#  'Mardy Fish': 40005305,
#  'Charles Howell III': 40000653,
#  'Jeff Sorenson': 40001350,
#  'John Huston': 40000667,
#  'Mo Lim': 40005306,
#  'Dylan Menante': 40005307,
#  'Ken Duke': 40000360,
#  'Jason Gore': 40000520,
#  'Preston Stanley': 40002289,
#  'Lucas Bjerregaard': 40000125,
#  'Mark Baldwin': 40000083,
#  'Pep Angles': 40002581,
#  'Francesco Laporta': 40001975,
#  'Julian Suri': 40002631,
#  'Nino Bertasio': 40002456,
#  'Espen Kofstad': 40002457,
#  'Joe Highsmith': 40004823,
#  'Alfredo Garcia-Heredia': 40003059,
#  'Ricardo Gouveia': 40001828,
#  'Benjamin Hébert': 40000603,
#  'Justin Warren': 40003791,
#  'David Longmire': 40003922,
#  'Scott Hend': 40000610,
#  'Tom Lewis': 40000856,
#  'Joel Stalter': 40001718,
#  'Joel Sjoholm': 40001320,
#  'Haydn Porteous': 40001637,
#  'Joshua McCarthy': 40004952,
#  'Hugo Leon': 40000845,
#  'Andrea Pavan': 40001129,
#  'Ollie Osborne': 40003668,
#  'Robin Roussel': 40002833,
#  'Albert Boneta': 40005304,
#  'Renato Paratore': 40001862,
#  'George Coetzee': 40000259,
#  'Anthony Quayle': 40002897,
#  'Lee Westwood': 40001543,
#  'Filippo Celli': 40004940,
#  'Robert Dinwiddie': 40000336,
#  'Brad Kennedy': 40001723,
#  'Lars Van Meijel': 40002794,
#  'Ian Poulter': 40001174,
#  'Justin De Los Santos': 40003366,
#  'Sam Bairstow': 40004871,
#  'Jamie Rutherford': 40002627,
#  'Mark Calcavecchia': 40000204,
#  'Ben Campbell': 40002617,
#  'Ashley Chesters': 40000240,
#  'Mingyu Cho': 40003323,
#  'Stephen Dodd': 40000340,
#  'David Duval': 40000368,
#  'Jorge Fernandez-Valdes': 40001673,
#  'Jack Floydd': 40004355,
#  'Matt Ford': 40002169,
#  'Matthew Griffin': 40002490,
#  'Justin Harding': 40000583,
#  'Sam Horsfield': 40000646,
#  'Chan Kim': 40002636,
#  'Minkyu Kim': 40002775,
#  'Paul Lawrie': 40000821,
#  'Jediah Morgan': 40003841,
#  'Ronan Mullarney': 40005301,
#  'Shaun Norris': 40002536,
#  'Dimi Papadatos': 40002609,
#  'Scott Vincent': 40001503,
#  'Bernd Wiesberger': 40001560,
#  'Alex Wrigley': 40002870,
#  'Patrick Flavin': 40003600,
#  'Josh Geary': 40000492,
#  'Carlos Pigem': 40002497,
#  'Conrad Shindler': 40001306,
#  'David Drysdale': 40000356,
#  'Alfredo Garcia': 40003209,
#  'Rikard Karlberg': 40000733,
#  'Frederic Lacroix': 40003578,
#  'Richard McEvoy': 40000957,
#  'Zach Murray': 40003353,
#  'Chris Paisley': 40002170,
#  'Andrew Stephens': 40004875,
#  'Richard Sterne': 40001375,
#  'Miguel Tabuena': 40001417,
#  'Matt Harris': 40005285,
#  'Niklas Lemke': 40000843,
#  'Nathan Petronzio': 40005278,
#  'Garrick Porteous': 40001170,
#  'Daniel Wetterich': 40003868,
#  'Michael Bradley': 40000153,
#  'Maclain Huge': 40005291,
#  'Mikko Korhonen': 40002162,
#  'Maverick Antcliff': 40003314,
#  'Kristoffer Broberg': 40000169,
#  'Steven Brown': 40002664,
#  'Jonathan Caldwell': 40002725,
#  'Stephen Gallacher': 40000469,
#  'Joachim B. Hansen': 40002171,
#  'Jaekyeong Lee': 40003696,
#  'Jack Senior': 40002433,
#  'Brandon Stone': 40001632,
#  'Danie Van Tonder': 40001486,
#  'Jeff Winther': 40002557,
#  'Chris Wood': 40001590,
#  'Daniel Berger': 40000115,
#  'Luke Gannon': 40004862,
#  'Sean McCarty': 40000947,
#  'John Senden': 40001296,
#  'Shawn Stefani': 40001370,
#  'Charles Jahn': 40005277,
#  'Matthew Wolff': 40003460,
#  "Adam D'Amario": 40003171,
#  'Todd Sinnott': 40002606,
#  'Stewart Hagestad': 40002502,
#  'Andrew Beckler': 40005247,
#  'Fred Biondi': 40005231,
#  'Brady Calkins': 40003971,
#  'Adrien Dumont De Chassart': 40005233,
#  'Keith Greene': 40005228,
#  'Daijiro Izumida': 40002797,
#  'Jinichiro Kozuma': 40002759,
#  'Ben Lorenz': 40005230,
#  'Caleb Manuel': 40005248,
#  'Matthew McCarty': 40005036,
#  'James Piot': 40005059,
#  'Fran Quinn': 40001195,
#  'Charles Reiter': 40002955,
#  'Isaiah Salinda': 40003721,
#  'Laird Shepherd': 40004853,
#  'Davis Shore': 40004822,
#  'Tomoyasu Sugiyama': 40003631,
#  'Bill Leonard': 40005246,
#  'Yi Cao': 40000217,
#  'Albin Choi': 40000243,
#  'Joseph Deraney': 40003596,
#  'Jared Du Toit': 40002448,
#  'A.J. Ewart': 40002218,
#  'Wes Heffernan': 40000606,
#  'Pat Perez': 40001137,
#  'William Buhl': 40005215,
#  'Callum Davison': 40005217,
#  'Brendan Leonard': 40005218,
#  'Max Sekulic': 40005219,
#  'Braden Thornberry': 40002638,
#  'Matt Jones': 40000720,
#  'Curtis Luck': 40002494,
#  'Hudson Swafford': 40001416,
#  'Ty Strafaci': 40002996,
#  'Rich Beem': 40000107,
#  'Brandon Bingaman': 40005157,
#  'Matthew Borchert': 40002368,
#  'Alex Cejka': 40000232,
#  'Paul Dickinson': 40005166,
#  'Tim Feenstra': 40005161,
#  'Austin Hurt': 40005160,
#  'Yuki Inamori': 40002553,
#  'Nic Ishee': 40005164,
#  'Jared Jones': 40005165,
#  'Ryosuke Kinoshita': 40003202,
#  'Kyle Mendoza': 40004383,
#  'Dylan Newman': 40005162,
#  'Zac Oakley': 40005158,
#  'Casey Pyne': 40005163,
#  'Ryan Vermeer': 40002692,
#  'Shawn Warren': 40003238,
#  'Peter Uihlein': 40001476,
#  'Kyle Wilshire': 40002303,
#  'Justin Leonard': 40000846,
#  'John Murphy': 40004946,
#  'Cooper Dossey': 40005114,
#  'James Du Preez': 40003763,
#  'Andrew Loupe': 40000881,
#  'Turk Pettit': 40004901,
#  'Eugenio Lopez-Chacarra': 40003639,
#  'Larkin Gross': 40004716,
#  'Gregory Odom': 40005134,
#  'Nicholas Thompson': 40001440,
#  'Norman Xiong': 40002973,
#  'Graeme McDowell': 40000954,
#  'Manuel Inman': 40001938,
#  'Ben Willman': 40001571,
#  'Santiago De La Fuente': 40005125,
#  'Jose Antonio Safa': 40005127,
#  'Bronson Burgoon': 40000192,
#  'Logan McAllister': 40005098,
#  'Sam Saunders': 40001267,
#  'Jake Kevorkian': 40004096,
#  'Jeronimo Estevez': 40000397,
#  'Andrew Filbert': 40002988,
#  'Matt Gogel': 40004385,
#  'Willy Pumarol': 40001790,
#  'Manuel Relancio': 40002008,
#  'Michael Balcar': 40005089,
#  'Blake Kennedy': 40002514,
#  'Andrew McCain': 40003867,
#  'Tyler McCumber': 40001781,
#  'Austin Connelly': 40000269,
#  'Eric Morales': 40001018,
#  'Alan Morin': 40001021,
#  'Roberto Nieves': 40004394,
#  'Chris Couch': 40001641,
#  'Smylie Kaufman': 40000738,
#  'Skip Kendall': 40000745,
#  'Rob Oppenheim': 40001093,
#  'Kristoffer Ventura': 40003179,
#  'Christian Salzer': 40005050,
#  'Xinjun Zhang': 40001623,
#  'Mark D. Anderson': 40000050,
#  'Rhein Gibson': 40000498,
#  'Martin Contini': 40005045,
#  'Chase Koepka': 40002510,
#  'Aaron Beverly': 40005052,
#  'Craig Hocknull': 40000629,
#  'Peter Jacobsen': 40000692,
#  'Tom Lehman': 40000841,
#  'Brad Marek': 40004717,
#  'Rod Pampling': 40001108,
#  'Billy Mayfair': 40000940,
#  'Ryan Alford': 40005031,
#  'Max Sear': 40005032,
#  'T.J. Vogel': 40001504,
#  'Mark Wilson': 40001577,
#  'Peter Jung': 40003461,
#  'Garrett Okamura': 40001086,
#  'Kevin Carll': 40000220,
#  'Andy Ogletree': 40004111,
#  'Bruce Doucett': 40003464,
#  'Koichiro Ishika': 40005028}
